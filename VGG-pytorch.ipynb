# %%
import torch
import torchvision
from torchvision import datasets, models, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np
import torch.nn as nn
import torch.optim as optim
from torchvision.datasets import ImageFolder

from google.colab import drive
drive.mount('/content/drive')

cfg = {
    'VGG11': [64, 'M', 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M'],
    'VGG16': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512, 'M', 512, 512, 512, 'M'],
}
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
class VGG(torch.nn.Module):
    def __init__(self, vgg_name):
        super(VGG, self).__init__()
        self.features = self._make_layers(cfg[vgg_name])
        #self.classifier = torch.nn.Linear(512, 10)
        self.classifier = nn.Sequential(
            nn.Linear(25088,4096),
            nn.ReLU(),
            nn.Dropout(p=0.5),
            nn.Linear(4096,4096),
            nn.ReLU(),
            torch.nn.Dropout(p=0.5),
            nn.Linear(4096,5)
        )

    def forward(self, x):
        out = self.features(x)
        out = out.view(out.size(0), -1)
        out = self.classifier(out)
        return out

    def _make_layers(self, cfg):
        layers = []
        in_channels = 3
        for x in cfg:
            if x == 'M':
                layers += [torch.nn.MaxPool2d(kernel_size=2, stride=2)]
            else:
                layers += [torch.nn.Conv2d(in_channels, x, kernel_size=3, padding=1), torch.nn.BatchNorm2d(x),
                           torch.nn.ReLU(inplace=True)]
                in_channels = x
        layers += [torch.nn.AvgPool2d(kernel_size=1, stride=1)]
        return torch.nn.Sequential(*layers)

# %%
vgg = VGG("VGG11").cuda()

transform = transforms.Compose([
        transforms.Resize((224,224)),
        #transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))
    ]
)


#flower_dataset = ImageFolder(root="./flowers", transform = transform)
flower_dataset = ImageFolder(root="/content/drive/My Drive/colab/flowers", transform = transform)

train_size = int(0.8 * len(flower_dataset))
test_size = len(flower_dataset) - train_size

train_dataset, test_dataset = torch.utils.data.random_split(flower_dataset, [train_size, test_size])

flower_train = DataLoader(train_dataset,batch_size = 128 , shuffle = True , num_workers= 0)
flower_test = DataLoader(test_dataset,batch_size = 128 , shuffle = True , num_workers= 0)

classes = ('daisy','dandelion','rose','sunflower','tulip')

# %%
# Define a Loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(vgg.parameters(),lr=0.001 , momentum= 0.9)

# Train the network
for epoch in range(15):
    for i,data in enumerate(flower_train,0):

        inputs,labels =data

        inputs = inputs.cuda()
        labels = labels.cuda()

        optimizer.zero_grad()
        outputs = vgg(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        print('代數:%d  次數:%5d loss: %.3f' %(epoch + 1, i + 1, loss.item()))

print('Finished Training')
# Out:
# 代數:1  次數:    1 loss: 1.607
# 代數:1  次數:    2 loss: 1.628
# 代數:1  次數:    3 loss: 1.624
# 代數:1  次數:    4 loss: 1.628
# 代數:1  次數:    5 loss: 1.582
# 代數:1  次數:    6 loss: 1.616
# 代數:1  次數:    7 loss: 1.498
# 代數:1  次數:    8 loss: 1.584
# 代數:1  次數:    9 loss: 1.562
# 代數:1  次數:   10 loss: 1.568
# 代數:1  次數:   11 loss: 1.547
# 代數:1  次數:   12 loss: 1.510
# 代數:1  次數:   13 loss: 1.550
# 代數:1  次數:   14 loss: 1.525
# 代數:1  次數:   15 loss: 1.457
# 代數:1  次數:   16 loss: 1.498
# 代數:1  次數:   17 loss: 1.496
# 代數:1  次數:   18 loss: 1.485
# 代數:1  次數:   19 loss: 1.485
# 代數:1  次數:   20 loss: 1.405
# 代數:1  次數:   21 loss: 1.365
# 代數:1  次數:   22 loss: 1.340
# 代數:1  次數:   23 loss: 1.408
# 代數:1  次數:   24 loss: 1.406
# 代數:1  次數:   25 loss: 1.352
# 代數:1  次數:   26 loss: 1.295
# 代數:1  次數:   27 loss: 1.336
# 代數:1  次數:   28 loss: 1.582
# 代數:2  次數:    1 loss: 1.259
# 代數:2  次數:    2 loss: 1.446
# 代數:2  次數:    3 loss: 1.301
# 代數:2  次數:    4 loss: 1.335
# 代數:2  次數:    5 loss: 1.353
# 代數:2  次數:    6 loss: 1.252
# 代數:2  次數:    7 loss: 1.285
# 代數:2  次數:    8 loss: 1.148
# 代數:2  次數:    9 loss: 1.201
# 代數:2  次數:   10 loss: 1.192
# 代數:2  次數:   11 loss: 1.175
# 代數:2  次數:   12 loss: 1.139
# 代數:2  次數:   13 loss: 1.183
# 代數:2  次數:   14 loss: 1.196
# 代數:2  次數:   15 loss: 1.137
# 代數:2  次數:   16 loss: 1.049
# 代數:2  次數:   17 loss: 1.132
# 代數:2  次數:   18 loss: 1.211
# 代數:2  次數:   19 loss: 1.237
# 代數:2  次數:   20 loss: 1.099
# 代數:2  次數:   21 loss: 1.158
# 代數:2  次數:   22 loss: 1.100
# 代數:2  次數:   23 loss: 1.057
# 代數:2  次數:   24 loss: 1.061
# 代數:2  次數:   25 loss: 1.100
# 代數:2  次數:   26 loss: 1.138
# 代數:2  次數:   27 loss: 1.154
# 代數:2  次數:   28 loss: 0.655
# 代數:3  次數:    1 loss: 1.100
# 代數:3  次數:    2 loss: 1.212
# 代數:3  次數:    3 loss: 1.132
# 代數:3  次數:    4 loss: 1.109
# 代數:3  次數:    5 loss: 1.089
# 代數:3  次數:    6 loss: 0.998
# 代數:3  次數:    7 loss: 0.983
# 代數:3  次數:    8 loss: 0.981
# 代數:3  次數:    9 loss: 0.986
# 代數:3  次數:   10 loss: 1.116
# 代數:3  次數:   11 loss: 1.099
# 代數:3  次數:   12 loss: 1.063
# 代數:3  次數:   13 loss: 0.973
# 代數:3  次數:   14 loss: 0.998
# 代數:3  次數:   15 loss: 0.952
# 代數:3  次數:   16 loss: 1.001
# 代數:3  次數:   17 loss: 0.933
# 代數:3  次數:   18 loss: 0.929
# 代數:3  次數:   19 loss: 1.061
# 代數:3  次數:   20 loss: 1.041
# 代數:3  次數:   21 loss: 0.964
# 代數:3  次數:   22 loss: 0.978
# 代數:3  次數:   23 loss: 1.043
# 代數:3  次數:   24 loss: 0.986
# 代數:3  次數:   25 loss: 0.978
# 代數:3  次數:   26 loss: 0.947
# 代數:3  次數:   27 loss: 1.018
# 代數:3  次數:   28 loss: 0.946
# 代數:4  次數:    1 loss: 0.911
# 代數:4  次數:    2 loss: 1.033
# 代數:4  次數:    3 loss: 1.169
# 代數:4  次數:    4 loss: 1.251
# 代數:4  次數:    5 loss: 1.106
# 代數:4  次數:    6 loss: 1.047
# 代數:4  次數:    7 loss: 0.964
# 代數:4  次數:    8 loss: 1.046
# 代數:4  次數:    9 loss: 0.964
# 代數:4  次數:   10 loss: 1.084
# 代數:4  次數:   11 loss: 1.139
# 代數:4  次數:   12 loss: 0.979
# 代數:4  次數:   13 loss: 1.019
# 代數:4  次數:   14 loss: 0.980
# 代數:4  次數:   15 loss: 0.993
# 代數:4  次數:   16 loss: 0.949
# 代數:4  次數:   17 loss: 0.975
# 代數:4  次數:   18 loss: 0.849
# 代數:4  次數:   19 loss: 0.768
# 代數:4  次數:   20 loss: 1.022
# 代數:4  次數:   21 loss: 0.848
# 代數:4  次數:   22 loss: 0.993
# 代數:4  次數:   23 loss: 0.850
# 代數:4  次數:   24 loss: 0.876
# 代數:4  次數:   25 loss: 0.795
# 代數:4  次數:   26 loss: 0.717
# 代數:4  次數:   27 loss: 0.840
# 代數:4  次數:   28 loss: 2.683
# 代數:5  次數:    1 loss: 0.839
# 代數:5  次數:    2 loss: 0.926
# 代數:5  次數:    3 loss: 1.124
# 代數:5  次數:    4 loss: 0.977
# 代數:5  次數:    5 loss: 1.098
# 代數:5  次數:    6 loss: 0.948
# 代數:5  次數:    7 loss: 0.850
# 代數:5  次數:    8 loss: 1.023
# 代數:5  次數:    9 loss: 0.984
# 代數:5  次數:   10 loss: 0.958
# 代數:5  次數:   11 loss: 0.883
# 代數:5  次數:   12 loss: 0.870
# 代數:5  次數:   13 loss: 1.016
# 代數:5  次數:   14 loss: 0.940
# 代數:5  次數:   15 loss: 0.980
# 代數:5  次數:   16 loss: 0.924
# 代數:5  次數:   17 loss: 0.851
# 代數:5  次數:   18 loss: 0.746
# 代數:5  次數:   19 loss: 0.790
# 代數:5  次數:   20 loss: 0.932
# 代數:5  次數:   21 loss: 1.044
# 代數:5  次數:   22 loss: 0.799
# 代數:5  次數:   23 loss: 0.901
# 代數:5  次數:   24 loss: 0.858
# 代數:5  次數:   25 loss: 0.866
# 代數:5  次數:   26 loss: 0.837
# 代數:5  次數:   27 loss: 0.937
# 代數:5  次數:   28 loss: 0.917
# 代數:6  次數:    1 loss: 0.884
# 代數:6  次數:    2 loss: 0.832
# 代數:6  次數:    3 loss: 0.858
# 代數:6  次數:    4 loss: 0.818
# 代數:6  次數:    5 loss: 0.698
# 代數:6  次數:    6 loss: 0.927
# 代數:6  次數:    7 loss: 0.939
# 代數:6  次數:    8 loss: 1.029
# 代數:6  次數:    9 loss: 0.780
# 代數:6  次數:   10 loss: 0.726
# 代數:6  次數:   11 loss: 0.756
# 代數:6  次數:   12 loss: 0.801
# 代數:6  次數:   13 loss: 1.082
# 代數:6  次數:   14 loss: 0.764
# 代數:6  次數:   15 loss: 0.936
# 代數:6  次數:   16 loss: 0.753
# 代數:6  次數:   17 loss: 0.787
# 代數:6  次數:   18 loss: 0.805
# 代數:6  次數:   19 loss: 0.868
# 代數:6  次數:   20 loss: 0.776
# 代數:6  次數:   21 loss: 0.684
# 代數:6  次數:   22 loss: 0.778
# 代數:6  次數:   23 loss: 0.811
# 代數:6  次數:   24 loss: 0.814
# 代數:6  次數:   25 loss: 0.628
# 代數:6  次數:   26 loss: 0.769
# 代數:6  次數:   27 loss: 0.986
# 代數:6  次數:   28 loss: 0.573
# 代數:7  次數:    1 loss: 0.855
# 代數:7  次數:    2 loss: 0.743
# 代數:7  次數:    3 loss: 0.691
# 代數:7  次數:    4 loss: 0.802
# 代數:7  次數:    5 loss: 0.852
# 代數:7  次數:    6 loss: 1.052
# 代數:7  次數:    7 loss: 0.880
# 代數:7  次數:    8 loss: 0.803
# 代數:7  次數:    9 loss: 0.819
# 代數:7  次數:   10 loss: 0.780
# 代數:7  次數:   11 loss: 0.812
# 代數:7  次數:   12 loss: 0.972
# 代數:7  次數:   13 loss: 0.909
# 代數:7  次數:   14 loss: 0.874
# 代數:7  次數:   15 loss: 0.641
# 代數:7  次數:   16 loss: 0.711
# 代數:7  次數:   17 loss: 0.844
# 代數:7  次數:   18 loss: 0.721
# 代數:7  次數:   19 loss: 0.718
# 代數:7  次數:   20 loss: 0.952
# 代數:7  次數:   21 loss: 0.761
# 代數:7  次數:   22 loss: 0.632
# 代數:7  次數:   23 loss: 0.687
# 代數:7  次數:   24 loss: 0.612
# 代數:7  次數:   25 loss: 0.822
# 代數:7  次數:   26 loss: 0.731
# 代數:7  次數:   27 loss: 0.757
# 代數:7  次數:   28 loss: 1.373
# 代數:8  次數:    1 loss: 0.806
# 代數:8  次數:    2 loss: 0.864
# 代數:8  次數:    3 loss: 1.127
# 代數:8  次數:    4 loss: 0.905
# 代數:8  次數:    5 loss: 0.984
# 代數:8  次數:    6 loss: 0.769
# 代數:8  次數:    7 loss: 0.681
# 代數:8  次數:    8 loss: 0.914
# 代數:8  次數:    9 loss: 0.714
# 代數:8  次數:   10 loss: 0.687
# 代數:8  次數:   11 loss: 0.729
# 代數:8  次數:   12 loss: 0.786
# 代數:8  次數:   13 loss: 0.776
# 代數:8  次數:   14 loss: 0.785
# 代數:8  次數:   15 loss: 0.746
# 代數:8  次數:   16 loss: 0.639
# 代數:8  次數:   17 loss: 0.805
# 代數:8  次數:   18 loss: 0.730
# 代數:8  次數:   19 loss: 0.690
# 代數:8  次數:   20 loss: 0.819
# 代數:8  次數:   21 loss: 0.922
# 代數:8  次數:   22 loss: 0.602
# 代數:8  次數:   23 loss: 0.805
# 代數:8  次數:   24 loss: 0.696
# 代數:8  次數:   25 loss: 0.759
# 代數:8  次數:   26 loss: 0.668
# 代數:8  次數:   27 loss: 0.793
# 代數:8  次數:   28 loss: 0.572
# 代數:9  次數:    1 loss: 0.633
# 代數:9  次數:    2 loss: 0.902
# 代數:9  次數:    3 loss: 0.791
# 代數:9  次數:    4 loss: 0.840
# 代數:9  次數:    5 loss: 0.669
# 代數:9  次數:    6 loss: 0.820
# 代數:9  次數:    7 loss: 0.713
# 代數:9  次數:    8 loss: 0.610
# 代數:9  次數:    9 loss: 0.719
# 代數:9  次數:   10 loss: 0.828
# 代數:9  次數:   11 loss: 0.687
# 代數:9  次數:   12 loss: 0.594
# 代數:9  次數:   13 loss: 0.682
# 代數:9  次數:   14 loss: 0.754
# 代數:9  次數:   15 loss: 0.679
# 代數:9  次數:   16 loss: 0.623
# 代數:9  次數:   17 loss: 0.515
# 代數:9  次數:   18 loss: 0.680
# 代數:9  次數:   19 loss: 0.618
# 代數:9  次數:   20 loss: 0.760
# 代數:9  次數:   21 loss: 0.818
# 代數:9  次數:   22 loss: 0.750
# 代數:9  次數:   23 loss: 0.789
# 代數:9  次數:   24 loss: 0.731
# 代數:9  次數:   25 loss: 0.660
# 代數:9  次數:   26 loss: 0.698
# 代數:9  次數:   27 loss: 0.731
# 代數:9  次數:   28 loss: 0.990
# 代數:10  次數:    1 loss: 0.537
# 代數:10  次數:    2 loss: 0.779
# 代數:10  次數:    3 loss: 0.846
# 代數:10  次數:    4 loss: 0.963
# 代數:10  次數:    5 loss: 0.967
# 代數:10  次數:    6 loss: 0.863
# 代數:10  次數:    7 loss: 0.900
# 代數:10  次數:    8 loss: 0.689
# 代數:10  次數:    9 loss: 0.692
# 代數:10  次數:   10 loss: 0.822
# 代數:10  次數:   11 loss: 0.686
# 代數:10  次數:   12 loss: 0.790
# 代數:10  次數:   13 loss: 0.712
# 代數:10  次數:   14 loss: 0.814
# 代數:10  次數:   15 loss: 0.671
# 代數:10  次數:   16 loss: 0.851
# 代數:10  次數:   17 loss: 0.720
# 代數:10  次數:   18 loss: 0.768
# 代數:10  次數:   19 loss: 0.756
# 代數:10  次數:   20 loss: 0.584
# 代數:10  次數:   21 loss: 0.652
# 代數:10  次數:   22 loss: 0.768
# 代數:10  次數:   23 loss: 0.754
# 代數:10  次數:   24 loss: 0.732
# 代數:10  次數:   25 loss: 0.777
# 代數:10  次數:   26 loss: 0.632
# 代數:10  次數:   27 loss: 0.647
# 代數:10  次數:   28 loss: 2.346
# 代數:11  次數:    1 loss: 0.654
# 代數:11  次數:    2 loss: 1.033
# 代數:11  次數:    3 loss: 1.004
# 代數:11  次數:    4 loss: 1.346
# 代數:11  次數:    5 loss: 1.082
# 代數:11  次數:    6 loss: 0.867
# 代數:11  次數:    7 loss: 0.849
# 代數:11  次數:    8 loss: 1.013
# 代數:11  次數:    9 loss: 0.987
# 代數:11  次數:   10 loss: 1.036
# 代數:11  次數:   11 loss: 1.055
# 代數:11  次數:   12 loss: 1.030
# 代數:11  次數:   13 loss: 0.921
# 代數:11  次數:   14 loss: 0.798
# 代數:11  次數:   15 loss: 0.860
# 代數:11  次數:   16 loss: 0.829
# 代數:11  次數:   17 loss: 0.888
# 代數:11  次數:   18 loss: 0.764
# 代數:11  次數:   19 loss: 0.842
# 代數:11  次數:   20 loss: 0.712
# 代數:11  次數:   21 loss: 0.754
# 代數:11  次數:   22 loss: 0.806
# 代數:11  次數:   23 loss: 0.753
# 代數:11  次數:   24 loss: 0.734
# 代數:11  次數:   25 loss: 0.812
# 代數:11  次數:   26 loss: 0.657
# 代數:11  次數:   27 loss: 0.754
# 代數:11  次數:   28 loss: 0.888
# 代數:12  次數:    1 loss: 0.712
# 代數:12  次數:    2 loss: 0.966
# 代數:12  次數:    3 loss: 0.867
# 代數:12  次數:    4 loss: 0.921
# 代數:12  次數:    5 loss: 0.955
# 代數:12  次數:    6 loss: 1.028
# 代數:12  次數:    7 loss: 0.903
# 代數:12  次數:    8 loss: 0.769
# 代數:12  次數:    9 loss: 0.895
# 代數:12  次數:   10 loss: 0.780
# 代數:12  次數:   11 loss: 0.755
# 代數:12  次數:   12 loss: 0.806
# 代數:12  次數:   13 loss: 0.786
# 代數:12  次數:   14 loss: 0.738
# 代數:12  次數:   15 loss: 0.639
# 代數:12  次數:   16 loss: 0.633
# 代數:12  次數:   17 loss: 0.656
# 代數:12  次數:   18 loss: 0.645
# 代數:12  次數:   19 loss: 0.786
# 代數:12  次數:   20 loss: 0.676
# 代數:12  次數:   21 loss: 0.694
# 代數:12  次數:   22 loss: 0.666
# 代數:12  次數:   23 loss: 0.729
# 代數:12  次數:   24 loss: 0.662
# 代數:12  次數:   25 loss: 0.830
# 代數:12  次數:   26 loss: 0.728
# 代數:12  次數:   27 loss: 0.657
# 代數:12  次數:   28 loss: 1.769
# 代數:13  次數:    1 loss: 0.635
# 代數:13  次數:    2 loss: 0.663
# 代數:13  次數:    3 loss: 0.755
# 代數:13  次數:    4 loss: 1.143
# 代數:13  次數:    5 loss: 0.894
# 代數:13  次數:    6 loss: 0.822
# 代數:13  次數:    7 loss: 0.725
# 代數:13  次數:    8 loss: 0.682
# 代數:13  次數:    9 loss: 0.803
# 代數:13  次數:   10 loss: 0.806
# 代數:13  次數:   11 loss: 0.790
# 代數:13  次數:   12 loss: 0.725
# 代數:13  次數:   13 loss: 0.668
# 代數:13  次數:   14 loss: 0.638
# 代數:13  次數:   15 loss: 0.774
# 代數:13  次數:   16 loss: 0.675
# 代數:13  次數:   17 loss: 0.651
# 代數:13  次數:   18 loss: 0.804
# 代數:13  次數:   19 loss: 0.745
# 代數:13  次數:   20 loss: 0.798
# 代數:13  次數:   21 loss: 0.616
# 代數:13  次數:   22 loss: 0.668
# 代數:13  次數:   23 loss: 0.672
# 代數:13  次數:   24 loss: 0.743
# 代數:13  次數:   25 loss: 0.677
# 代數:13  次數:   26 loss: 0.768
# 代數:13  次數:   27 loss: 0.580
# 代數:13  次數:   28 loss: 0.838
# 代數:14  次數:    1 loss: 0.638
# 代數:14  次數:    2 loss: 0.806
# 代數:14  次數:    3 loss: 0.593
# 代數:14  次數:    4 loss: 0.729
# 代數:14  次數:    5 loss: 0.627
# 代數:14  次數:    6 loss: 0.612
# 代數:14  次數:    7 loss: 0.654
# 代數:14  次數:    8 loss: 0.622
# 代數:14  次數:    9 loss: 0.629
# 代數:14  次數:   10 loss: 0.727
# 代數:14  次數:   11 loss: 0.769
# 代數:14  次數:   12 loss: 0.855
# 代數:14  次數:   13 loss: 0.522
# 代數:14  次數:   14 loss: 0.729
# 代數:14  次數:   15 loss: 0.489
# 代數:14  次數:   16 loss: 0.549
# 代數:14  次數:   17 loss: 0.689
# 代數:14  次數:   18 loss: 0.609
# 代數:14  次數:   19 loss: 0.596
# 代數:14  次數:   20 loss: 0.572
# 代數:14  次數:   21 loss: 0.717
# 代數:14  次數:   22 loss: 0.580
# 代數:14  次數:   23 loss: 0.725
# 代數:14  次數:   24 loss: 0.587
# 代數:14  次數:   25 loss: 0.588
# 代數:14  次數:   26 loss: 0.736
# 代數:14  次數:   27 loss: 0.449
# 代數:14  次數:   28 loss: 0.420
# 代數:15  次數:    1 loss: 0.636
# 代數:15  次數:    2 loss: 0.617
# 代數:15  次數:    3 loss: 0.808
# 代數:15  次數:    4 loss: 0.730
# 代數:15  次數:    5 loss: 0.603
# 代數:15  次數:    6 loss: 0.786
# 代數:15  次數:    7 loss: 0.591
# 代數:15  次數:    8 loss: 0.544
# 代數:15  次數:    9 loss: 0.698
# 代數:15  次數:   10 loss: 0.690
# 代數:15  次數:   11 loss: 0.624
# 代數:15  次數:   12 loss: 0.553
# 代數:15  次數:   13 loss: 0.590
# 代數:15  次數:   14 loss: 0.545
# 代數:15  次數:   15 loss: 0.702
# 代數:15  次數:   16 loss: 0.557
# 代數:15  次數:   17 loss: 0.704
# 代數:15  次數:   18 loss: 0.571
# 代數:15  次數:   19 loss: 0.519
# 代數:15  次數:   20 loss: 0.555
# 代數:15  次數:   21 loss: 0.585
# 代數:15  次數:   22 loss: 0.579
# 代數:15  次數:   23 loss: 0.588
# 代數:15  次數:   24 loss: 0.529
# 代數:15  次數:   25 loss: 0.783
# 代數:15  次數:   26 loss: 0.551
# 代數:15  次數:   27 loss: 0.648
# 代數:15  次數:   28 loss: 1.448
# Finished Training

# %%
correct = 0
total = 0
with torch.no_grad():
    for data in flower_test:
        images, labels = data

        images = images.cuda()
        labels = labels.cuda()

        outputs = vgg(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('測試資料成功率: %d %%' % (
    100 * correct / total))
# Out:
# 測試資料成功率: 71 %

# %%
class_correct = list(0. for i in range(5))
class_total = list(0. for i in range(5))
with torch.no_grad():
    for data in flower_test:
        images, labels = data

        images = images.cuda()
        labels = labels.cuda()

        outputs = vgg(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1


for i in range(5):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of daisy : 75 %
# Accuracy of dandelion : 100 %
# Accuracy of  rose : 87 %
# Accuracy of sunflower : 25 %
# Accuracy of tulip : 66 %
